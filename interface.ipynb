# %%
import tkinter as tk
import numpy as np
import pandas as pd
import holoviews as hv
hv.extension('bokeh' , 'matplotlib')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.bk-hbox {
#     display: flex;
#     justify-content: center;
# }
#
# div.bk-hbox div.bk-plot {
#     padding: 8px;
# }
#
# div.bk-hbox div.bk-data-table {
#     padding: 20px;
# }
#
# div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
# ...

# %%
# load in the data outputted by pipeline
df = pd.read_csv('output.csv', encoding ="ISO-8859-1")
print(df.shape)
# Out:
# (2213, 29)

# %%
# Some basic visualizations. What more can we do here??
#print=("THE DATA RANGES FROM BLALH TO BLAH)

layout = hv.Scatter(df, 'neg', 'compound') + hv.Scatter(df, 'pos', 'compound')
# is there a  correlation between the neg/pos score and the overall compound score?
layout
#scatter.data to get underlying data that is being used
# Out:
# :Layout
#    .Scatter.I  :Scatter   [neg]   (compound)
#    .Scatter.II :Scatter   [pos]   (compound)

# %%
print("From above, it looks like the relation is not linear but logarithmic in nature")
# Out:
# From above, it looks like the relation is not linear but logarithmic in nature

# %%
#independent vars in our dataset: date-time, location, etc.

pie_raw_holo_table = hv.Table(df, kdims=['Country', 'Binary Sentiment'])
sources_chart = pie_raw_holo_table.aggregate('Country', function=np.count_nonzero).to.bars(group='Where is our feedback coming from?')
flavors_chart = pie_raw_holo_table.aggregate('Binary Sentiment', function=np.count_nonzero).to.bars(group='Breakdown of Happy/Sad Overall')
sources_chart
# Out:
# :Bars   [Country]   (Unnamed: 0,Response ID,Time Started,Date Submitted,Status,Language,Referer,Extended Referer,User Agent,Extended User Agent,Longitude,Latitude,City,State/Region,Postal,OS,Positive Feedback,Negative Feedback,Relevant Site,compound,neg,neu,pos,Sites,Issues,Components,Processed Feedback)

# %%
sources_chart.data.sort_values(by='Unnamed: 0', ascending=False)
# Out:
#                          Country  Unnamed: 0  Response ID  Time Started  \
# 1                  United States        1131         1131          1131
# 18                         India         153          153           153
# 4                 United Kingdom         150          150           150
# 0                         Canada         136          136           136
# 2                      Australia          64           64            64
# 22                       Nigeria          51           51            51
# 30                  South Africa          28           28            28
# 21                     Indonesia          27           27            27
# 8                    Netherlands          26           26            26
# 7      Iran, Islamic Republic of          23           23            23
# 12                   Philippines          23           23            23
# 43                       Romania          19           19            19
# ...

# %%
#TESTING GRAPHS
#just trying these out and will repurpose to fit our needs
from holoviews.operation.timeseries import rolling, rolling_outlier_std
from holoviews.streams import Stream

#trend graphs, breakdown of Y/N sentiment by category

# %%
'''
Here we will use the same example exploring a dataset of stock timeseries
and build a small dashboard using the paramBokeh library, 
which allows us to declare easily declare custom widgets 
and link them to our streams. Let's just jump to using our dat directly 

'''
#display(df.head())
results_df = df 
# bars = hv.Bars(results_df, hv.Dimension('Country'), 'Count')
# bars
# def load_symbol(symbol, variable='adj_close', **kwargs):
#     df = pd.DataFrame(getattr(stocks, symbol))
#     df['date'] = df.date.astype('datetime64[ns]')
#     return hv.Curve(df, ('date', 'Date'), variable)

# stock_symbols = ['AAPL', 'IBM', 'FB', 'GOOG', 'MSFT']
# issue_cats = ['Bu']
# dmap = hv.DynamicMap(load_symbol, kdims='Symbol').redim.values(Symbol=stock_symbols)
# dmap
from itertools import product
np.random.seed(3)
index, groups = ['United States', 'Canada', 'Australia'], ['Happy', 'Sad']
keys = product(index, groups)
count_sentiment_by_country = lambda key_pair: len(df.groupby(['Country','Binary Sentiment']).groups[key_pair[0], key_pair[1]])


bars = hv.Bars([k+(np.random.rand()*100.,) for k in keys],
               ['Country', 'Happy/Sad'], 'Count')
bars.relabel(group='Binary Sentiment by Country')
# Out:
#   File "<ipython-input-105-20999c99c006>", line 27
#     %%opts Bars [stack_index=1 xrotation=90 width=600 show_legend=False tools=['hover']]
#     ^
# SyntaxError: invalid syntax

# %%
print("Next steps: fix categorization bug s.t. we can show breakdown by issue/component category\n")
print("Add dynamic drop down of list of countries, or slider that toggles how many coutnries to show\nNeed to add formatting")
# Out:
# Next steps: fix categorization bug s.t. we can show breakdown by issue/component category
#
# Add dynamic drop down of list of countries, or slider that toggles how many coutnries to show
# Need to add formatting

# %%
macro_df = pd.read_csv('http://assets.holoviews.org/macro.csv', '\t')
key_dimensions   = [('year', 'Time'), ('country', 'Country')]
value_dimensions = [('unem', 'Unemployment'), ('capmob', 'Capital Mobility'),
                    ('gdp', 'Feedback Count'), ('trade', 'Trade')]
macro = hv.Table(macro_df, key_dimensions, value_dimensions)
marco_df.year = macro_df.year + 20
gdp_curves = macro.to.curve('Time', 'Feedback Count')
#gdp_unem_scatter = macro.to.scatter('Year', ['GDP Growth', 'Unemployment'])
annotations = hv.Arrow(1973, 8, 'V62 Released', 'v') * hv.Arrow(1975, 6, 'V23 Android Mobile', 'v') *\
hv.Arrow(1979, 8, 'V63 Beta', 'v') * hv.Arrow(1981.9, 5, 'V63 Released', 'v')
gdp_curves * gdp_unem_scatter* annotations
# Out:
# :HoloMap   [country]
#    :Overlay
#       .Curve.I   :Curve   [year]   (gdp)
#       .Scatter.I :Scatter   [year]   (gdp,unem)
#       .Arrow.I   :Arrow   [x,y]
#       .Arrow.II  :Arrow   [x,y]
#       .Arrow.III :Arrow   [x,y]
#       .Arrow.IV  :Arrow   [x,y]
